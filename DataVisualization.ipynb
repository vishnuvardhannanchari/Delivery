# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\real\\fake\\Food_Delivery_Times.csv")  # change name if different
df.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
df.columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'],
#       dtype='object')

# %%
df.rename(columns={'Time_taken(min)': 'Delivery_Time'}, inplace=True)

# %%
df = df.dropna()

# %%
df['Delivery_Time_min'].mean()
# Out:
# np.float64(56.425821064552665)

# %%
plt.figure()
plt.hist(df['Delivery_Time_min'], bins=20)
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Number of Orders")
plt.title("Delivery Time Distribution")
plt.show()

# %%
plt.figure()
plt.scatter(df['Distance_km'], df['Delivery_Time_min'])
plt.xlabel("Distance (km)")
plt.ylabel("Delivery Time (minutes)")
plt.title("Distance vs Delivery Time")
plt.show()

# %%
sns.boxplot(x='Traffic_Level', y='Delivery_Time_min', data=df)
plt.title("Traffic Level vs Delivery Time")
plt.show()

# %%
sns.boxplot(x='Weather', y='Delivery_Time_min', data=df)
plt.title("Weather vs Delivery Time")
plt.show()

# %%
sns.boxplot(x='Vehicle_Type', y='Delivery_Time_min', data=df)
plt.title("Vehicle Type vs Delivery Time")
plt.show()

# %%
sns.boxplot(x='Time_of_Day', y='Delivery_Time_min', data=df)
plt.title("Time of Day vs Delivery Time")
plt.show()

# %%
plt.figure()
plt.scatter(df['Preparation_Time_min'], df['Delivery_Time_min'])
plt.xlabel("Preparation Time (minutes)")
plt.ylabel("Delivery Time (minutes)")
plt.title("Preparation Time vs Delivery Time")
plt.show()

# %%
plt.figure()
plt.scatter(df['Courier_Experience_yrs'], df['Delivery_Time_min'])
plt.xlabel("Courier Experience (years)")
plt.ylabel("Delivery Time (minutes)")
plt.title("Courier Experience vs Delivery Time")
plt.show()

# %%
df.groupby('Traffic_Level')['Delivery_Time_min'].mean()
# Out:
# Traffic_Level
# High      64.298343
# Low       52.498559
# Medium    56.250704
# Name: Delivery_Time_min, dtype: float64

# %%
df.sort_values('Delivery_Time_min').head(10)
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 43        975         1.11   Clear           Low     Morning         Bike
# 242       515         1.38   Clear        Medium     Evening      Scooter
# 277       604         2.23   Clear           Low     Morning         Bike
# 512       336         1.29   Rainy           Low     Evening         Bike
# 198       614         2.09   Clear        Medium     Evening         Bike
# 357       425         1.62   Windy           Low     Evening         Bike
# 139        73         0.61   Clear           Low   Afternoon      Scooter
# 775       899         0.75   Clear        Medium   Afternoon         Bike
# 959        59         1.38   Clear        Medium     Morning          Car
# 306       335         1.40   Windy           Low     Evening         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 43                      5                     6.0                  8
# 242                     5                     8.0                 13
# 277                     7                     6.0                 14
# 512                     7                     7.0                 15
# 198                     5                     5.0                 16
# 357                     9                     8.0                 16
# 139                    10                     0.0                 16
# 775                    10                     5.0                 16
# 959                     6                     3.0                 17
# 306                     9                     9.0                 17
